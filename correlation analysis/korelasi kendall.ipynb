# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
import math

data = pd.read_csv('crash2.csv')
data
# Out:
#     Jumlah Kecelakaan Lalu Lintas (kasus)   Faktor Pengemudi (orang)   \
# 0                                      107                         56
# 1                                      113                         63
# 2                                      117                         60
# 3                                      129                         61
# 4                                      137                         77
# 5                                       99                         54
# 6                                      112                         56
# 7                                      114                         56
# 8                                      126                         60
# 9                                      101                         65
# 10                                     116                         56
# 11                                     103                         59
#
#     Faktor Jalan (kasus)   Faktor Kendaraan (kasus)   \
# ...

# %%
data2=data.iloc[:,[2,3]]

data2
# Out:
#     Faktor Jalan (kasus)   Faktor Kendaraan (kasus)
# 0                      31                         12
# 1                      23                         15
# 2                      27                         14
# 3                      33                          9
# 4                      31                         18
# 5                      20                         11
# 6                      30                         10
# 7                      27                         11
# 8                      20                         13
# 9                      17                          9
# 10                     32                         21
# 11                     29                         14

# %%
kendal=data2.corr(method="kendall")
kendal
# Out:
#                            Faktor Jalan (kasus)   Faktor Kendaraan (kasus)
# Faktor Jalan (kasus)                    1.000000                   0.190476
# Faktor Kendaraan (kasus)                0.190476                   1.000000

# %% [markdown]
# disini kenapa saya menggunakan rumus cepat ??
#
# Karena jika saya menggunakan rumus manual
#
# 1. mengurutkan salah satu data yang ada X atau Y nya
# 2. setelah diurutkan data yang tidak di urutkn dicari nilai concordan dan disconcordan
# 3. lalu menggunakan rumus kendall

# %% [markdown]
# APA ITU CONCORDAN??
#
# YAITU NILAI YANG LEBIH BANYAK DARI NILAI ATASNYA DAN YANG DI TULIS BUKAN TOTAL NILAI, NAMUN ADA BERAPA BANYAK.
# MISAL ADA NILAI 2 10 6 5 1
#
# NILAI YANG LEBIH DARI 2 ADA 3 MAKA BUAT TABEL BARU DAN TULIS 3, NANTI SETELAH ITU DI JUMLAH

# %% [markdown]
# DISCONCORDAN??
#
# BEDANYA CUMA NILAI YANG LEBIH KECIL DARI BAWAHNYA JIKA TIDAK ADA TULIS 0

# %%
from IPython.display import Image

# Menampilkan gambar
image_path = "korelasi_kendall.png"
Image(filename=image_path)
